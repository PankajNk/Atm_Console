# %% [markdown]
# # Python Mini Project (AUTOMATED TELLER MACHINE)

# %% [markdown]
# # Password 2020

# %%
#creating class that holds all operation of bank
class BankAccount:
    def __init__(self):
        self.balance=0.0
        self.check_bal = 1000
        
    #deposit function  
    def Deposit(self):
        amount=float(input("Enter The Amount To Deposit "))
        if amount < 0:
            print("Really,Minus Amount")
        else:
            self.balance = self.balance + amount
            print("${} is Deposited to your Account".format(amount))
            print("=====================================")
            print("Your Current Balance is  ${}".format(self.balance))
            print("=====================================")
    
    #withdraw function
    def Withdrawl(self):
        amount=float(input("Enter The Amount to withdrawl "))
        if amount < 0:
            print("Really,Minus Amount")
        else:
            if self.balance <= amount:
                print("Not Efficient Amount to Withdraw")
            else:
                self.balance = self.balance - amount
                print("${} is withdrawl from account".format(amount))
                print("=====================================")
                print("Your current balance is $",self.balance)
                print("=====================================")
    #balance dispaly function        
    def print_balance(self):
        print("=====================================")
        print("Your Current Saving Balance is : $",self.balance)
        print("=====================================")
    
    #transfer function
    def Transfer(self):
        
        print("*************************************")
        print("NOW YOU ARE IN CHECK BALANCE")
        print("You Have $ 1000.0 In Check Balance")
        while True:
            
            
            print("\nPlease Choose The Option ")
            print("""
                      1 == Withdrawl From Check Balance
                      2 == Deposit To Check Balance
                      3 == Exit from Check Balance
                """)
            try:
                select = int(input("Enter Yours Choice "))

                if select == 1:
                    c_balance = float(input("Enter The Amount to be Withdraw from Check Balance "))
                    if c_balance < 0:
                        print("Really,Minus Amount")

                    else:
                        
                        if c_balance > self.check_bal:
                            print("\n Not Efficient Amount to Withdraw")
                            print("=====================================")
                            print("Current Amount In Saving Balance $",self.balance)
                            print("Current Amount In Check Balance $ {}".format(self.check_bal))
                            print("=====================================")
                        else:

                            self.check_bal = self.check_bal - c_balance
                            print("${} Amount Is  Withdraw from Check Balance To Saving Balance".format(c_balance))
                            self.balance = self.balance + c_balance

                            print("=====================================")
                            print("Current Amount In Saving Balance $",self.balance)
                            print("Current Amount In Check Balance $ {}".format(self.check_bal))
                            print("=====================================")
                elif select ==2 :
                    c_balance = float(input("Enter The Amount To Be Deposit To Check Balance"))
                    if c_balance < 0:
                        print("Really,Minus Amount")
                    else:

                        if  c_balance >= self.balance:
                            print("\n Not Efficient Amount to Withdraw")
                            print("=====================================")
                            print("Current Amount In Saving Balance $",self.balance)
                            print("Current Amount In Check Balance $ {}".format(self.check_bal))
                            print("=====================================")
                        else:
                            self.check_bal = self.check_bal + c_balance
                            print("${} amount is Deposit to Check Balance".format(c_balance))
                            self.balance = self.balance - c_balance
                            if self.balance <= 0:
                            #and self.check_bal < 0:
                                self.balance=0
                                #self.check_bal=0
                                print("=====================================")
                                print("Current Amount Of Saving Balance1 $",self.balance)
                                print("Current Amount Of Check Balance $ {}".format(self.check_bal))
                                print("=====================================")
                            else:
                                print("=====================================")
                                print("Current Amount Of Saving Balance $",self.balance)
                                print("Current Amount Of Check Balance $ {}".format(self.check_bal))
                                print("=====================================")
                else:
                    print("**************************************")
                    print("OUT OF CHECK BALANCE ")
                    break
            except:
                print("invalid input")
     
    # password checking function
    def password_check(self):
        password =2020
        
        while True:
            try:
                input_pass = int(input("\nEnter 4 Digit PIN "))
                input_pass1 = int(input("Re-Enter The PIN "))
                
                if input_pass != input_pass1:
                    print("Pin Doesn't Match")    
                elif input_pass and input_pass1 == password:
                    print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
                    print("YOU HAVE SUCCESSFULLY LOG IN TO  ACCOUNT ")
                    break
                else:
                        print("Exception")
            except:
                print("Pin Can not Be is Blank or Space or Special Character ")
            
# object of class            
a = BankAccount()

#password = 2020
#balance=0
print("*********************************************")
print("      WELCOME TO NIELT SAVING ACCOUNT        ")
print("*********************************************")
print("Account Name : Pankaj Naik ")

#calling pssword from bankaccount class 
a.password_check()

while True:
    print("\nPlease choose the option ")
    print("""
             1 == Check Balance
             2 == Deposit Fund 
             3 == Withdrawl Fund
             4 == Transfer Fund
             5 == Log Out
      """)
    # iterations 
    try:
        option =int(input("Enter your choice "))

        if option == 1:
            a.print_balance()   
        elif option == 2 :
            a.Deposit()
        elif option == 3 :
            a.Withdrawl()
        elif option ==4:
            a.Transfer()
        elif option ==5:
            print("THANK YOU FOR CHOOSING NIELT BANK ")
            print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
            break
    except:
        print("Please Enter Invalid Input")
# Out:
# *********************************************
#       WELCOME TO NIELT SAVING ACCOUNT
# *********************************************
# Account Name : Pankaj Naik
#
# Enter 4 Digit PIN 2020
# Re-Enter The PIN 2020
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# YOU HAVE SUCCESSFULLY LOG IN TO  ACCOUNT
#
# Please choose the option
#
#              1 == Check Balance
#              2 == Deposit Fund
#              3 == Withdrawl Fund
#              4 == Transfer Fund
#              5 == Log Out
#
# Enter your choice 1
# ...
# Your Current Saving Balance is : $ 0.0
# ...
#
# Please choose the option
#
#              1 == Check Balance
#              2 == Deposit Fund
#              3 == Withdrawl Fund
#              4 == Transfer Fund
#              5 == Log Out
#
# Enter your choice 2
# Enter The Amount To Deposit 5000
# $5000.0 is Deposited to your Account
# ...
# Your Current Balance is  $5000.0
# ...
#
# Please choose the option
#
#              1 == Check Balance
#              2 == Deposit Fund
# ...
